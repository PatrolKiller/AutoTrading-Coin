# %%
from simul_Long_Trend import trading

# 시작 날짜 입력
startyear = 2020
startmonth = 4
startday = 15
# 종료 날짜 입력
endyear = 2020
endmonth = 12
endday = 31

trading(startyear, startmonth, startday, endyear, endmonth, endday)
# Out:
# ---------------------------------------------
# 2020-04-15 00:00:00
# 기다리는중
# 총 평가 자산 = 10,000달러
# ---------------------------------------------
# 2020-04-16 00:00:00
# 기다리는중
# 총 평가 자산 = 10,000달러
# ---------------------------------------------
# 2020-04-17 00:00:00
# 기다리는중
# 총 평가 자산 = 10,000달러
# 2020-4-18 영업일 아님
# 2020-4-19 영업일 아님
# ---------------------------------------------
# 2020-04-20 00:00:00
# ※ 5달러 이하 200달러 이상 종목 삭제 중 ※
# HTTP Error 404: Not Found  - symbol "BRKB"not found or invalid periods
# HTTP Error 404: Not Found  - symbol "BFB"not found or invalid periods
# HTTP Error 400: Bad Request  - symbol "CEG"not found or invalid periods
# HTTP Error 400: Bad Request  - symbol "OGN"not found or invalid periods
# ※ 5달러 이하 200달러 이상 종목 삭제 완료 ※
# 440
# ※ 평균 거래 금액 2억5천만달러 이하 삭제 중 ※
# ※ 평균 거래 금액 2억5천만달러 이하 삭제 완료 ※
# 163
# ※ 변동률 순위 구하는 중 ※
# ※ 변동률 순위 구하기 완료 ※
# 지갑 위치 = 1
# TSLA:  1000.0
# 종가 =  50.259335
# 주식 갯수 =  19
# 내가 산 금액 = 955달러
# 내가 산 주식 명 : TSLA
# 매수 체결
# ...
